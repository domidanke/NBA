# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import metrics
from sklearn import preprocessing
import csv
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
from sklearn.metrics import r2_score
from sklearn.model_selection import GridSearchCV

pd.options.mode.chained_assignment = None
data = pd.read_csv('../2019Data/StatsAfterAllNBAInsertion.csv')

# %%
data.describe()
# Out:
#                Year           Age       All NBA   All NBA Acc  \
# count  15100.000000  15100.000000  15100.000000  15100.000000
# mean    2004.197550     26.984834      0.027483      0.276358
# std        7.998757      4.149146      0.163493      1.305299
# min     1990.000000     18.000000      0.000000      0.000000
# 25%     1997.000000     24.000000      0.000000      0.000000
# 50%     2005.000000     26.000000      0.000000      0.000000
# 75%     2011.000000     30.000000      0.000000      0.000000
# max     2017.000000     44.000000      1.000000     15.000000
#
#        All NBA Total Career             G            GS            MP  \
# count          15100.000000  15100.000000  15100.000000  15100.000000
# mean               0.430993     48.339603     23.073907   1130.345695
# std                1.765006     26.478508     28.236547    915.995235
# min                0.000000      1.000000      0.000000      0.000000
# 25%                0.000000     25.000000      0.000000    292.000000
# 50%                0.000000     52.000000      8.000000    940.000000
# 75%                0.000000     74.000000     43.000000   1835.250000
# max               15.000000     85.000000     83.000000   3533.000000
#
#                MPpG           PER      ...                STL         STLpG  \
# count  15100.000000  15095.000000      ...       15100.000000  15100.000000
# mean      19.823603     12.399821      ...          36.770662      0.642278
# std       10.293082      6.282646      ...          36.014443      0.466536
# min        0.000000    -90.600000      ...           0.000000      0.000000
# 25%       11.200000      9.600000      ...           8.000000      0.300000
# 50%       18.900000     12.600000      ...          27.000000      0.600000
# 75%       28.300000     15.600000      ...          55.000000      0.900000
# max       44.500000    129.100000      ...         246.000000      3.500000
#
#                 BLK         BLKpG           TOV         TOVpG            PF  \
# count  15100.000000  15100.000000  15100.000000  15100.000000  15100.000000
# mean      23.103245      0.398854     67.158808      1.190523    101.926821
# std       34.770722      0.497782     62.887391      0.794410     76.944305
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        3.000000      0.100000     16.000000      0.600000     32.000000
# 50%       11.000000      0.200000     50.000000      1.000000     92.000000
# 75%       28.000000      0.500000    102.000000      1.600000    159.000000
# max      376.000000      6.000000    464.000000      5.700000    371.000000
#
#                PFpG           PTS         PTSpG
# count  15100.000000  15100.000000  15100.000000
# mean       1.864801    461.931854      7.824821
# std        0.851711    461.987449      5.834517
# min        0.000000      0.000000      0.000000
# 25%        1.200000     86.000000      3.300000
# 50%        1.900000    317.000000      6.300000
# 75%        2.500000    713.250000     11.200000
# max        6.000000   2832.000000     35.400000
#
# [8 rows x 66 columns]

# %%
# Fill in blanks/NAs

data['PER'] = data['PER'].fillna(data['PER'].median())
data['TS%'] = data['TS%'].fillna(data['TS%'].median())
data['3PAr'] = data['3PAr'].fillna(data['3PAr'].median())
data['FTr'] = data['FTr'].fillna(data['FTr'].median())
data['ORB%'] = data['ORB%'].fillna(data['ORB%'].median())
data['DRB%'] = data['DRB%'].fillna(data['DRB%'].median())
data['TRB%'] = data['TRB%'].fillna(data['TRB%'].median())
data['AST%'] = data['AST%'].fillna(data['AST%'].median())
data['STL%'] = data['STL%'].fillna(data['STL%'].median())
data['BLK%'] = data['BLK%'].fillna(data['BLK%'].median())
data['TOV%'] = data['TOV%'].fillna(data['TOV%'].median())
data['USG%'] = data['USG%'].fillna(data['USG%'].median())
data['WS/48'] = data['WS/48'].fillna(data['WS/48'].median())
data['FG%'] = data['FG%'].fillna(data['FG%'].median())
data['3P%'] = data['3P%'].fillna(data['3P%'].median())
data['2P%'] = data['2P%'].fillna(data['2P%'].median())
data['eFG%'] = data['eFG%'].fillna(data['eFG%'].median())
data['FT%'] = data['FT%'].fillna(data['FT%'].median())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15100 entries, 0 to 15099
# Data columns (total 68 columns):
# Year                    15100 non-null int64
# Player                  15100 non-null object
# Age                     15100 non-null int64
# Pos                     15100 non-null object
# All NBA                 15100 non-null int64
# All NBA Acc             15100 non-null int64
# All NBA Total Career    15100 non-null int64
# G                       15100 non-null int64
# GS                      15100 non-null int64
# MP                      15100 non-null int64
# MPpG                    15100 non-null float64
# PER                     15100 non-null float64
# TS%                     15100 non-null float64
# 3PAr                    15100 non-null float64
# FTr                     15100 non-null float64
# ORB%                    15100 non-null float64
# DRB%                    15100 non-null float64
# TRB%                    15100 non-null float64
# AST%                    15100 non-null float64
# STL%                    15100 non-null float64
# BLK%                    15100 non-null float64
# TOV%                    15100 non-null float64
# USG%                    15100 non-null float64
# OWS                     15100 non-null float64
# DWS                     15100 non-null float64
# WS                      15100 non-null float64
# WS/48                   15100 non-null float64
# OBPM                    15100 non-null float64
# DBPM                    15100 non-null float64
# BPM                     15100 non-null float64
# VORP                    15100 non-null float64
# FG                      15100 non-null int64
# FGpG                    15100 non-null float64
# FGA                     15100 non-null int64
# FGApG                   15100 non-null float64
# FG%                     15100 non-null float64
# 3P                      15100 non-null int64
# 3PpG                    15100 non-null float64
# 3PA                     15100 non-null int64
# 3PApG                   15100 non-null float64
# 3P%                     15100 non-null float64
# 2P                      15100 non-null int64
# 2PA                     15100 non-null int64
# 2P%                     15100 non-null float64
# eFG%                    15100 non-null float64
# FT                      15100 non-null int64
# FTpG                    15100 non-null float64
# FTA                     15100 non-null int64
# FTApG                   15100 non-null float64
# FT%                     15100 non-null float64
# ORB                     15100 non-null int64
# ORBpG                   15100 non-null float64
# DRB                     15100 non-null int64
# DRBpG                   15100 non-null float64
# TRB                     15100 non-null int64
# TRBpG                   15100 non-null float64
# AST                     15100 non-null int64
# ASTpG                   15100 non-null float64
# STL                     15100 non-null int64
# STLpG                   15100 non-null float64
# BLK                     15100 non-null int64
# BLKpG                   15100 non-null float64
# TOV                     15100 non-null int64
# TOVpG                   15100 non-null float64
# PF                      15100 non-null int64
# PFpG                    15100 non-null float64
# PTS                     15100 non-null int64
# PTSpG                   15100 non-null float64
# dtypes: float64(41), int64(25), object(2)
# memory usage: 7.8+ MB

# %%
data.Pos.unique()
# Out:
# array(['PF', 'SF', 'C', 'SG', 'PG', 'SG-SF', 'PF-C', 'SF-PF', 'PF-SF',
#        'SG-PG', 'PG-SG', 'C-PF', 'C-SF', 'SF-SG', 'PG-SF', 'SG-PF'],
#       dtype=object)

# %%
#Give Position numerical labels

le = preprocessing.LabelEncoder()
data['Pos'] = le.fit_transform(data['Pos'].astype(str))
le_Pos_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print(le_Pos_mapping)
# Out:
# {'C': 0, 'C-PF': 1, 'C-SF': 2, 'PF': 3, 'PF-C': 4, 'PF-SF': 5, 'PG': 6, 'PG-SF': 7, 'PG-SG': 8, 'SF': 9, 'SF-PF': 10, 'SF-SG': 11, 'SG': 12, 'SG-PF': 13, 'SG-PG': 14, 'SG-SF': 15}

# %%
# Delete duplicate Data that occured when Player transferred mid season

check = 0
index = 0
for year in data['Year']:
    if (check != year):
        check = year
        index = index + 1
        continue
    #remove row using index
    data = data.drop(index)
    index = index + 1

# %%
# Check if duplicate deletion was successful

def checkForDuplicates(dataframe):
    check = 0
    count = 0
    for year in dataframe['Year']:
        if (count == 2):
            return True
        if (check != year):
            check = year
            count = 0
            continue
        count = count + 1
        continue
    return False

# %%
print(checkForDuplicates(data))
# Out:
# False

# %%
# Split Dataset into sub-Datasets containing information about single players and careers per Dataframe

subDataSets = []
count = 0
string = 'A.C. Green'
for i,k in data.iterrows():
    if (string != k['Player']):
        subDataSets.append(data.loc[count:i-1])
        count = i
        string = k['Player']
    if (i == len(data)-1):
        subDataSets.append(data.loc[count:i])

# %%
# Optional, only use players with at least 5 entries

careerPlayers = []
for subset in subDataSets:
    if (len(subset) >= 5):
        careerPlayers.append(subset)

# %%
# Loop through every single player's career and take averages of all features
# Use mode to determine the most played position
# Write result into a new csv file for further usage

with open('../2019Data/AverageStats.csv', 'a') as f1:
    for dataFrame in careerPlayers:
        dfTmp = dataFrame.groupby('Player').mean()
        dfTmp['Pos'] = dataFrame.mode()['Pos'][0]
        # Initially left out
        # dfTmp['Age'] = dataFrame.max()['Age']
        dfTmp.round(2).to_csv(f1, header=False)

# %%
# Include names of columns/headers

averageData = pd.read_csv('../2019Data/AverageStats.csv',names=['Player','Year','Age','Pos','All NBA','All NBA Acc','All NBA Total Career','G','GS','MP','MPpG','PER','TS%',
       '3PAr','FTr','ORB%','DRB%','TRB%','AST%','STL%','BLK%','TOV%','USG%','OWS','DWS','WS','WS/48','OBPM','DBPM','BPM',
       'VORP','FG','FGpG','FGA','FGApG','FG%','3P','3PpG','3PA','3PApG','3P%','2P','2PA','2P%','eFG%','FT','FTpG','FTA',
       'FTApG','FT%','ORB','ORBpG','DRB','DRBpG','TRB','TRBpG','AST','ASTpG','STL','STLpG','BLK','BLKpG','TOV','TOVpG',
       'PF','PFpG','PTS','PTSpG'])
averageData.head()
# Out:
#          Player     Year    Age   Pos  All NBA  All NBA Acc  \
# 0    A.C. Green  1995.50  31.50   3.0      0.0          0.0
# 1    A.J. Price  2012.50  25.50   6.0      0.0          0.0
# 2  Aaron Brooks  2012.56  27.56   6.0      0.0          0.0
# 3    Aaron Gray  2011.00  26.00   0.0      0.0          0.0
# 4   Aaron McKie  2001.00  28.00  12.0      0.0          0.0
#
#    All NBA Total Career      G     GS       MP  ...      STL  STLpG    BLK  \
# 0                   0.0  79.42  51.08  2302.00  ...    61.08   0.77  26.42
# 1                   0.0  43.50   4.17   654.83  ...    20.83   0.43   1.50
# 2                   0.0  68.11  20.22  1472.22  ...    39.22   0.57   9.67
# 3                   0.0  45.43  12.43   550.14  ...    13.43   0.30  12.43
# 4                   0.0  61.00  22.08  1473.54  ...    70.15   1.03  12.62
#
#    BLKpG     TOV  TOVpG      PF  PFpG     PTS  PTSpG
# 0   0.33   82.83   1.02  138.33  1.72  744.42   9.23
# 1   0.03   38.17   0.80   39.50  0.82  253.83   5.35
# 2   0.14  109.89   1.56  132.11  1.89  687.11   9.61
# 3   0.26   37.86   0.81   96.86  2.09  152.29   3.24
# 4   0.20   81.46   1.22  122.15  1.85  451.62   6.63
#
# [5 rows x 68 columns]

# %%
# Drop irrelevant features

averageData = averageData.drop('Player', axis=1)
averageData = averageData.drop('Year', axis=1)
# maybe drop age maybe not 
averageData = averageData.drop('Age', axis=1)
averageData = averageData.drop('All NBA', axis=1)
averageData = averageData.drop('All NBA Acc', axis=1)
averageData.head()
# Out:
#     Pos  All NBA Total Career      G     GS       MP   MPpG    PER   TS%  \
# 0   3.0                   0.0  79.42  51.08  2302.00  28.65  13.81  0.53
# 1   6.0                   0.0  43.50   4.17   654.83  13.77  11.72  0.48
# 2   6.0                   0.0  68.11  20.22  1472.22  20.84  12.79  0.52
# 3   0.0                   0.0  45.43  12.43   550.14  11.99  11.56  0.53
# 4  12.0                   0.0  61.00  22.08  1473.54  22.26  11.73  0.50
#
#    3PAr   FTr  ...      STL  STLpG    BLK  BLKpG     TOV  TOVpG      PF  PFpG  \
# 0  0.06  0.42  ...    61.08   0.77  26.42   0.33   82.83   1.02  138.33  1.72
# 1  0.47  0.17  ...    20.83   0.43   1.50   0.03   38.17   0.80   39.50  0.82
# 2  0.41  0.19  ...    39.22   0.57   9.67   0.14  109.89   1.56  132.11  1.89
# 3  0.00  0.38  ...    13.43   0.30  12.43   0.26   37.86   0.81   96.86  2.09
# 4  0.20  0.21  ...    70.15   1.03  12.62   0.20   81.46   1.22  122.15  1.85
#
#       PTS  PTSpG
# 0  744.42   9.23
# 1  253.83   5.35
# 2  687.11   9.61
# 3  152.29   3.24
# 4  451.62   6.63
#
# [5 rows x 63 columns]

# %%
# Create correlation matrix

corr_matrix = averageData.corr().abs()

# Select upper triangle of correlation matrix

upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95

to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]
to_drop
# Out:
# ['MPpG',
#  'TRB%',
#  'WS',
#  'FGpG',
#  'FGA',
#  'FGApG',
#  '3PpG',
#  '3PA',
#  '3PApG',
#  '2P',
#  '2PA',
#  'FTpG',
#  'FTA',
#  'FTApG',
#  'ORBpG',
#  'DRBpG',
#  'TRB',
#  'TRBpG',
#  'ASTpG',
#  'STLpG',
#  'BLKpG',
#  'TOVpG',
#  'PTS',
#  'PTSpG']

# %%
# Drop the highly corelated features from dataframe

for feature in to_drop:
    if (feature == 'All NBA Total Career'):
        continue
    averageData = averageData.drop(feature, axis=1)

# %%
# Split dataframe into train and test sets aiming for ALL NBA TOTAL CAREER

X = averageData.drop("All NBA Total Career", axis=1)
y = averageData["All NBA Total Career"]

test_ratio = 0.2
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_ratio, shuffle=False, random_state=1)
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
# Out:
# (803, 38) (803,)
# (201, 38) (201,)

# %%
# Train the linear regression algorithm using default parameters

r = LinearRegression()  
r.fit(X_train, y_train)
y_pred = r.predict(X_test)
df1 = pd.DataFrame({'Actual': y_test, 'Predicted All NBA': y_pred})
df1
# Out:
#       Actual  Predicted All NBA
# 803      0.0           1.726595
# 804      0.0           0.003138
# 805      0.0          -0.031225
# 806      0.0           0.362500
# 807      1.0           2.042371
# 808      0.0          -0.450931
# 809      0.0           0.085328
# 810      0.0           0.072151
# 811      0.0          -0.077814
# 812      0.0           0.327857
# 813      0.0           1.148613
# 814      0.0           0.062967
# 815      0.0           1.182870
# 816      0.0          -0.886336
# 817      0.0          -0.807373
# 818      0.0          -0.375800
# 819      0.0          -0.608292
# 820      0.0           1.277799
# 821      0.0           0.049000
# 822      0.0          -0.027831
# 823      0.0           0.846509
# 824      0.0           0.139193
# 825      0.0           0.785156
# 826      0.0           0.548240
# 827      0.0           1.094575
# 828      0.0           0.318343
# 829      6.0           6.810543
# 830      0.0           0.301515
# 831      0.0          -0.393259
# 832      0.0          -0.269797
# ...      ...                ...
# 974      0.0          -0.284545
# 975      0.0          -0.027117
# 976      0.0           0.775908
# 977      0.0          -0.400732
# 978      0.0           0.795719
# 979      0.0           0.017759
# 980      0.0          -0.254722
# 981      0.0          -0.160686
# 982      0.0           0.431950
# 983      0.0          -0.577904
# 984      0.0          -1.074767
# 985      0.0          -0.512282
# 986      0.0          -0.015208
# 987      0.0           0.117602
# 988      0.0          -0.569911
# 989      0.0          -0.018221
# 990      0.0           0.485125
# 991      0.0          -0.022946
# 992      0.0          -0.312380
# 993      0.0          -0.647764
# 994      0.0          -0.880385
# 995      0.0           0.072852
# 996      0.0           0.925901
# 997      5.0           3.884593
# 998      0.0          -1.303801
# 999      1.0           1.484014
# 1000     0.0          -0.402689
# 1001     0.0          -0.411693
# 1002     0.0          -0.423523
# 1003     0.0          -0.542405
#
# [201 rows x 2 columns]

# %%
r2_score(y_test, y_pred)
# Out:
# 0.6008153314565092

# %%
# Perform Grid Search Cross Validation for parameter selection

param_grid = {
    'fit_intercept': [True, False],
    'normalize': [True, False],
    'copy_X': [True, False]
}

gs = GridSearchCV(LinearRegression(), param_grid)
gs.fit(X_train, y_train)

print("Tuned Parameters: {}".format(gs.best_params_))
print("Best accuracy is %.3f" %gs.best_score_)
# Out:
# Tuned Parameters: {'copy_X': True, 'fit_intercept': True, 'normalize': False}
# Best accuracy is 0.576

# %%
# Train another linear regression algorithm using best parameters

r2 = LinearRegression(fit_intercept=False,normalize=True, copy_X=True)  
r2.fit(X_train, y_train)
y_pred2 = r2.predict(X_test)
df2 = pd.DataFrame({'Actual': y_test, 'Predicted All NBA': y_pred2})
df2
# Out:
#       Actual  Predicted All NBA
# 803      0.0           1.620590
# 804      0.0           0.078563
# 805      0.0           0.083598
# 806      0.0           0.352423
# 807      1.0           1.952499
# 808      0.0          -0.593160
# 809      0.0           0.070048
# 810      0.0           0.077502
# 811      0.0          -0.062350
# 812      0.0           0.339660
# 813      0.0           1.395912
# 814      0.0          -0.005643
# 815      0.0           1.259343
# 816      0.0          -0.866285
# 817      0.0          -0.832016
# 818      0.0          -0.655285
# 819      0.0          -0.655279
# 820      0.0           1.053845
# 821      0.0           0.131439
# 822      0.0          -0.104783
# 823      0.0           0.697232
# 824      0.0           0.307213
# 825      0.0           0.789402
# 826      0.0           0.539732
# 827      0.0           1.127159
# 828      0.0           0.283270
# 829      6.0           6.905134
# 830      0.0           0.340371
# 831      0.0          -0.425049
# 832      0.0           0.086545
# ...      ...                ...
# 974      0.0          -0.333246
# 975      0.0           0.081391
# 976      0.0           0.642609
# 977      0.0          -0.649156
# 978      0.0           0.776447
# 979      0.0          -0.009374
# 980      0.0          -0.261086
# 981      0.0          -0.358005
# 982      0.0           0.444965
# 983      0.0          -0.573505
# 984      0.0          -0.964047
# 985      0.0          -0.318803
# 986      0.0          -0.050178
# 987      0.0           0.212235
# 988      0.0          -0.540291
# 989      0.0           0.007207
# 990      0.0           0.567582
# 991      0.0          -0.021390
# 992      0.0          -0.265347
# 993      0.0          -0.526866
# 994      0.0          -0.787204
# 995      0.0          -0.353505
# 996      0.0           0.753662
# 997      5.0           3.893370
# 998      0.0          -1.178722
# 999      1.0           1.468688
# 1000     0.0          -0.322355
# 1001     0.0          -0.385690
# 1002     0.0          -0.267855
# 1003     0.0           0.042405
#
# [201 rows x 2 columns]

# %%
r2_score(y_test, y_pred2)
# Out:
# 0.6011306866773194

# %%
dataCurrent = pd.read_csv('../2019Data/2019Data.csv')
dataCurrent.head()
# Out:
#    Year              Player  Age  Pos  All NBA  All NBA Acc  \
# 0  2019         Luka Doncic   20    9        0            0
# 1  2016  Karl-Anthony Towns   20    0        0            0
# 2  2017  Karl-Anthony Towns   21    0        0            0
# 3  2018  Karl-Anthony Towns   22    0        1            1
# 4  2019  Karl-Anthony Towns   23    0        1            2
#
#    All NBA Total Career   G  GS    MP  ...    STL  STLpG  BLK  BLKpG  TOV  \
# 0                     0  72  72  2318  ...     77    1.1   25    0.3  247
# 1                     2  82  82  2627  ...     58    0.7  138    1.7  183
# 2                     2  82  82  3030  ...     57    0.7  103    1.3  212
# 3                     2  82  82  2918  ...     64    0.8  115    1.4  159
# 4                     2  77  77  2545  ...     67    0.9  125    1.6  240
#
#    TOVpG   PF  PFpG   PTS  PTSpG
# 0    3.4  137   1.9  1526   21.2
# 1    2.2  245   3.0  1503   18.3
# 2    2.6  241   2.9  2061   25.1
# 3    1.9  285   3.5  1743   21.3
# 4    3.1  292   3.8  1880   24.4
#
# [5 rows x 68 columns]

# %%
# Create new csv file with Towns', Irving's, Doncic's, and Curry's current career average stats  

with open('../2019Data/AverageStats2019.csv', 'a') as f2:
    dfTmp = dataCurrent.groupby('Player').mean()
    dfTmp.round(2).to_csv(f2, header=False)

# %%
Average2019 = pd.read_csv('../2019Data/AverageStats2019.csv',names=['Player','Year','Age','Pos','All NBA','All NBA Acc','All NBA Total Career','G','GS','MP','MPpG','PER','TS%',
       '3PAr','FTr','ORB%','DRB%','TRB%','AST%','STL%','BLK%','TOV%','USG%','OWS','DWS','WS','WS/48','OBPM','DBPM','BPM',
       'VORP','FG','FGpG','FGA','FGApG','FG%','3P','3PpG','3PA','3PApG','3P%','2P','2PA','2P%','eFG%','FT','FTpG','FTA',
       'FTApG','FT%','ORB','ORBpG','DRB','DRBpG','TRB','TRBpG','AST','ASTpG','STL','STLpG','BLK','BLKpG','TOV','TOVpG',
       'PF','PFpG','PTS','PTSpG'])
Average2019.head()
# Out:
#                Player    Year    Age  Pos  All NBA  All NBA Acc  \
# 0  Karl-Anthony Towns  2017.5  21.50  0.0     0.50         0.75
# 1        Kyrie Irving  2015.5  22.75  6.0     0.25         0.75
# 2         Luka Doncic  2019.0  20.00  9.0     0.00         0.00
# 3       Stephen Curry  2014.5  25.50  6.0     0.60         2.10
#
#    All NBA Total Career      G     GS       MP  ...      STL  STLpG     BLK  \
# 0                   2.0  80.75  80.75  2780.00  ...     61.5   0.78  120.25
# 1                   2.0  63.50  63.50  2146.12  ...     84.0   1.31   22.25
# 2                   0.0  72.00  72.00  2318.00  ...     77.0   1.10   25.00
# 3                   6.0  69.40  68.80  2385.90  ...    120.1   1.69   15.40
#
#    BLKpG     TOV  TOVpG      PF  PFpG      PTS  PTSpG
# 0   1.50  198.50   2.45  265.75  3.30  1796.75  22.28
# 1   0.35  167.75   2.65  139.75  2.20  1411.75  16.60
# 2   0.30  247.00   3.40  137.00  1.90  1526.00  21.20
# 3   0.24  216.30   3.07  172.10  2.46  1631.50  23.06
#
# [4 rows x 68 columns]

# %%
# manually insert current ages of 4 players
#Average2019['Age'][0] = 23
#Average2019['Age'][1] = 27
#Average2019['Age'][2] = 20
#Average2019['Age'][3] = 30
#Average2019.head()

# %%
# Drop irrelevant features

Average2019 = Average2019.drop('Player', axis=1)
Average2019 = Average2019.drop('Year', axis=1)
Average2019 = Average2019.drop('Age', axis=1)
Average2019 = Average2019.drop('All NBA', axis=1)
Average2019 = Average2019.drop('All NBA Acc', axis=1)
Average2019.head()
# Out:
#    Pos  All NBA Total Career      G     GS       MP   MPpG    PER   TS%  3PAr  \
# 0  0.0                   2.0  80.75  80.75  2780.00  34.42  24.92  0.62  0.20
# 1  6.0                   2.0  63.50  63.50  2146.12  33.58  22.08  0.57  0.30
# 2  9.0                   0.0  72.00  72.00  2318.00  32.20  19.68  0.55  0.43
# 3  6.0                   6.0  69.40  68.80  2385.90  33.88  23.91  0.62  0.47
#
#     FTr  ...      STL  STLpG     BLK  BLKpG     TOV  TOVpG      PF  PFpG  \
# 0  0.30  ...     61.5   0.78  120.25   1.50  198.50   2.45  265.75  3.30
# 1  0.25  ...     84.0   1.31   22.25   0.35  167.75   2.65  139.75  2.20
# 2  0.41  ...     77.0   1.10   25.00   0.30  247.00   3.40  137.00  1.90
# 3  0.23  ...    120.1   1.69   15.40   0.24  216.30   3.07  172.10  2.46
#
#        PTS  PTSpG
# 0  1796.75  22.28
# 1  1411.75  16.60
# 2  1526.00  21.20
# 3  1631.50  23.06
#
# [4 rows x 63 columns]

# %%
# Drop previously highly correlated features from new dataframe

for feature in to_drop:
    if (feature == 'All NBA Total Career'):
        continue
    Average2019 = Average2019.drop(feature, axis=1)

# %%
X2019 = Average2019.drop('All NBA Total Career', axis=1)
y2019 = Average2019['All NBA Total Career']

# %%
# Use previous model to predict All NBA Total Career based on current career's stats

names = ['Towns', 'Irving', 'Doncic', 'Curry']
y2019_pred = r.predict(X2019)
df3 = pd.DataFrame({'Actual': names, 'Predicted All NBA': y2019_pred})
df3
# Out:
#    Actual  Predicted All NBA
# 0   Towns           5.756389
# 1  Irving           3.114552
# 2  Doncic           3.244805
# 3   Curry           4.921377

# %%
# Use previous model to predict All NBA Total Career based on current career's stats

names = ['Towns', 'Irving', 'Doncic', 'Curry']
y2019_pred2 = r2.predict(X2019)
df3 = pd.DataFrame({'Actual': names, 'Predicted All NBA': y2019_pred2})
df3
# Out:
#    Actual  Predicted All NBA
# 0   Towns           5.769229
# 1  Irving           2.986670
# 2  Doncic           3.534361
# 3   Curry           4.552660

# %%
# Therefore, All NBA Selections remaining are calculated by subtracting the current accumulated All NBA Selections
# from the predicted Total Career rounded to the higher integer.


# Included every single player:
# All NBA included:

# Towns:     7 - 2 = 5
# Irving:    4 - 2 = 2
# Doncic:    0 - 0 = 0
# Curry:     8 - 6 = 2

# If All NBA is deleted:

# Towns:     6 - 2 = 4
# Irving:    4 - 2 = 2
# Doncic:    5 - 0 = 5
# Curry:     5 - 6 = -1 -> No remaining All NBA

# Included only 5 entry players:

# If All NBA is included:

# Towns:     7 - 2 = 5
# Irving:    3 - 2 = 1
# Doncic:    0 - 0 = 0
# Curry:     8 - 6 = 2

# If All NBA is dropped:

# Towns:     6 - 2 = 4
# Irving:    3 - 2 = 1
# Doncic:    4 - 0 = 4
# Curry:     5 - 6 = -1 -> No remaining All NBA

# %%
# Same process but using only Position and PER

dataPER = pd.read_csv('../2019Data/StatsAfterAllNBAInsertionPER.csv')
dataPER.head()
# Out:
#    Year      Player  Age Pos  All NBA Total Career   PER
# 0  1990  A.C. Green   26  PF                     0  14.7
# 1  1991  A.C. Green   27  PF                     0  13.8
# 2  1992  A.C. Green   28  PF                     0  16.7
# 3  1993  A.C. Green   29  PF                     0  16.3
# 4  1994  A.C. Green   30  PF                     0  17.0

# %%
le2 = preprocessing.LabelEncoder()
dataPER['Pos'] = le2.fit_transform(dataPER['Pos'].astype(str))
le_Pos_mapping2 = dict(zip(le2.classes_, le2.transform(le2.classes_)))
print(le_Pos_mapping2)
# Out:
# {'C': 0, 'C-PF': 1, 'C-SF': 2, 'PF': 3, 'PF-C': 4, 'PF-SF': 5, 'PG': 6, 'PG-SF': 7, 'PG-SG': 8, 'SF': 9, 'SF-PF': 10, 'SF-SG': 11, 'SG': 12, 'SG-PF': 13, 'SG-PG': 14, 'SG-SF': 15}

# %%
dataPER['PER'] = dataPER['PER'].fillna(dataPER['PER'].median())
dataPER.info()

# %%
check = 0
index = 0
for year in dataPER['Year']:
    if (check != year):
        check = year
        index = index + 1
        continue
    #remove row using index
    dataPER = dataPER.drop(index)
    index = index + 1

# %%
checkForDuplicates(dataPER)

# %%
subDataSetsPER = []
count = 0
string = 'A.C. Green'
for i,k in dataPER.iterrows():
    if (string != k['Player']):
        subDataSetsPER.append(dataPER.loc[count:i-1])
        count = i
        string = k['Player']
    if (i == len(dataPER)-1):
        subDataSetsPER.append(dataPER.loc[count:i])

# %%
with open('../2019Data/AveragePER.csv', 'a') as f2:
    for dataFrame in subDataSetsPER:
        dfTmp = dataFrame.groupby('Player').mean()
        dfTmp['Pos'] = dataFrame.mode()['Pos'][0]
        dfTmp.round(2).to_csv(f2, header=False)

# %%
averagePER = pd.read_csv('../2019Data/AveragePER.csv',names=['Player','Year','Age','Pos','All NBA Total Career','PER per Season'])

# %%
averagePER.info()

# %%
averagePER = averagePER[['Pos', 'All NBA Total Career', 'PER per Season']]

# %%
XPER = averagePER.drop("All NBA Total Career", axis=1)
yPER = averagePER["All NBA Total Career"]

test_ratio = 0.2
X_train, X_test, y_train, y_test = train_test_split(XPER, yPER, test_size=test_ratio, shuffle=False, random_state=1)
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)

# %%
rPER = LinearRegression()  
rPER.fit(X_train, y_train) #training the algorithm
y_predPER = rPER.predict(X_test)
df = pd.DataFrame({'Actual': y_test, 'Predicted All NBA': y_predPER})
df

# %%
r2_score(y_test, y_predPER)

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'fit_intercept': [True, False],
    'normalize': [True, False],
    'copy_X': [True, False]
}

gs = GridSearchCV(LinearRegression(), param_grid)
gs.fit(X_train, y_train)

print("Tuned Parameters: {}".format(gs.best_params_))
print("Best accuracy is %.3f" %gs.best_score_)

# %%
rPER2 = LinearRegression(normalize=False)  
rPER2.fit(X_train, y_train) #training the algorithm
y_predPER2 = rPER2.predict(X_test)
df4 = pd.DataFrame({'Actual': y_test, 'Predicted All NBA': y_predPER2})
df4

# %%
r2_score(y_test, y_predPER2)

# %%
averagePERCurrent = pd.read_csv('../2019DataPERAverage.csv')
averagePERCurrent.head()

# %%
XPERCurrent = averagePERCurrent.drop('All NBA Total Career',axis=1)
yPERCurrent = rPER.predict(XPERCurrent)

# %%
yPERCurrent = rPER.predict(XPERCurrent)

# %%
df5 = pd.DataFrame({'Actual': names, 'Predicted All NBA': yPERCurrent})
df5

# %%
#DONE # average, one line per player,points whole career & points per season
# data.describe()
# include PER only first
# https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# year player raus
# include position
# no prediction overkill
# include whole career for all 4 players and mean and delete from original set
# cross validation

# %%
#data.corr()

# %%
#corr = data.corr()
#plt.subplots(figsize=(24,18))
#ax = sns.heatmap(corr)
